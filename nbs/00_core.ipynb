# %% [markdown]
# # core
#
# > Fill in a module description here

# %%
#| default_exp core

# %%
#| hide
from nbdev.showdoc import *

# %%
def add(a, b):
    result = a + b
    return result

# %%
show_doc(add)
# Out:
# ---
#
# ### add
#
# >      add (a, b)

# %%
#| export
def foo(): pass

# %%
#| hide
import nbdev; nbdev.nbdev_export()
